# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
from matplotlib.pyplot import figure
from matplotlib import rc
from matplotlib import font_manager
mpl.rcParams['axes.linewidth'] = 2 #set the value globally
font_dirs = ['/scratch/user/peterchao1/font/']
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)

for font_file in font_files:
    font_manager.fontManager.addfont(font_file)
mpl.rcParams["font.family"] = "Calibri"

# %%
Pred_exp_Rg_BAA = np.load('Pred_exp_Rg_BAA.npy')
Pred_exp_Rg_CE = np.load('Pred_exp_Rg_CE.npy')
exp_Rg = np.load('exp_Rg.npy')
Pred_exp_Rg_BAA_DNN = np.load('Pred_exp_Rg_BAA_DNN_BAA.npy')

# %%
Pred_exp_Rg_BAA[5]
# Out:
# array([15.23884482, 17.14918614, 18.9478536 , 22.64079855, 21.41378113,
#        20.28726887, 22.06912394, 18.23537167, 21.29645521, 22.38408091,
#        22.65067208, 17.31595983, 19.41840999, 23.96438514, 17.33016481,
#        21.26358995, 19.5016451 , 23.06061572, 18.9154966 , 14.01761762,
#        20.15842044, 22.60944513, 20.37529922, 22.60942101, 21.91097796,
#        22.60942965, 21.18164818, 21.87594382, 22.94059319, 22.60942416,
#        22.60961348, 22.60942416, 20.18228025, 21.2950373 , 23.09714819,
#        21.5355435 , 22.87840666, 22.56050866, 23.5524019 , 22.60995205,
#        23.24929058, 22.69711378])

# %%
fig, ax = plt.subplots()
ax.scatter(Pred_exp_Rg_CE, Pred_exp_Rg_BAA[5],s=25,color='#4575b4',alpha=0.5,edgecolors='none')
ax.plot([0, 60], 
        [0, 60], 'k--', lw=2.5)
plt.xlabel('Predicted Values by Count Encoding',fontsize=20)
plt.ylabel('Predicted Values by BAA',fontsize=20)
plt.axvline(x=32.10008298116191,linestyle ='--',color='#4575b4')
ax.set_aspect('equal', adjustable='box')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlim(0,60)
plt.ylim(0,60)
plt.savefig('Exp_CE_BAA.png',dpi=400,bbox_inches='tight')

# %%
fig, ax = plt.subplots()
ax.scatter(exp_Rg, Pred_exp_Rg_BAA[5],s=25,color='#4575b4',alpha=0.5,edgecolors='none')
ax.plot([0, 60], 
        [0, 60], 'k--', lw=2.5)
plt.xlabel('Experimental Values',fontsize=20)
plt.ylabel('Predicted Values by BAA',fontsize=20)
plt.axvline(x=32.10008298116191,linestyle ='--',color='#4575b4')
ax.set_aspect('equal', adjustable='box')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlim(0,60)
plt.ylim(0,60)
plt.savefig('Exp_BAA.png',dpi=400,bbox_inches='tight')

# %%
fig, ax = plt.subplots()
ax.scatter(exp_Rg, Pred_exp_Rg_CE,s=25,color='#4575b4',alpha=0.5,edgecolors='none')
ax.plot([0, 60], 
        [0, 60], 'k--', lw=2.5)
plt.xlabel('Experimental Values',fontsize=20)
plt.ylabel('Predicted Values by Count Encoding',fontsize=20)
plt.axvline(x=32.10008298116191,linestyle ='--',color='#4575b4')
ax.set_aspect('equal', adjustable='box')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlim(0,60)
plt.ylim(0,60)
plt.savefig('Exp_CE.png',dpi=400,bbox_inches='tight')

# %%
len(exp_Rg)
# Out:
# 42
