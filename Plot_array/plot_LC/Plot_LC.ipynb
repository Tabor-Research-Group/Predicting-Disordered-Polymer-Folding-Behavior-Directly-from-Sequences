# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
from matplotlib.pyplot import figure
from matplotlib import rc
from matplotlib import font_manager
mpl.rcParams['axes.linewidth'] = 2 #set the value globally
font_dirs = ['/scratch/user/peterchao1/font/']
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)

for font_file in font_files:
    font_manager.fontManager.addfont(font_file)
mpl.rcParams["font.family"] = "Calibri"

# %%
CE_GPR_LC_train_loss = np.load('CE_GPR_LC_train_loss.npy')
CE_GPR_LC_train_score = np.load('CE_GPR_LC_train_score.npy')
CE_GPR_LC_val_loss = np.load('CE_GPR_LC_val_loss.npy')
CE_GPR_LC_val_score = np.load('CE_GPR_LC_val_score.npy')

CE_KRR_LC_train_loss = np.load('CE_KRR_LC_train_loss.npy')
CE_KRR_LC_train_score = np.load('CE_KRR_LC_train_score.npy')
CE_KRR_LC_val_loss = np.load('CE_KRR_LC_val_loss.npy')
CE_KRR_LC_val_score = np.load('CE_KRR_LC_val_score.npy')

CE_LRR_LC_train_loss = np.load('CE_LRR_LC_train_loss.npy')
CE_LRR_LC_train_score = np.load('CE_LRR_LC_train_score.npy')
CE_LRR_LC_val_loss = np.load('CE_LRR_LC_val_loss.npy')
CE_LRR_LC_val_score = np.load('CE_LRR_LC_val_score.npy')

CE_SVR_LC_train_loss = np.load('CE_SVR_LC_train_loss.npy')
CE_SVR_LC_train_score = np.load('CE_SVR_LC_train_score.npy')
CE_SVR_LC_val_loss = np.load('CE_SVR_LC_val_loss.npy')
CE_SVR_LC_val_score = np.load('CE_SVR_LC_val_score.npy')

OE_GPR_LC_train_loss = np.load('OE_GPR_LC_train_loss.npy')
OE_GPR_LC_train_score = np.load('OE_GPR_LC_train_score.npy')
OE_GPR_LC_val_loss = np.load('OE_GPR_LC_val_loss.npy')
OE_GPR_LC_val_score = np.load('OE_GPR_LC_val_score.npy')

OE_KRR_LC_train_loss = np.load('OE_KRR_LC_train_loss.npy')
OE_KRR_LC_train_score = np.load('OE_KRR_LC_train_score.npy')
OE_KRR_LC_val_loss = np.load('OE_KRR_LC_val_loss.npy')
OE_KRR_LC_val_score = np.load('OE_KRR_LC_val_score.npy')

OE_LRR_LC_train_loss = np.load('OE_LRR_LC_train_loss.npy')
OE_LRR_LC_train_score = np.load('OE_LRR_LC_train_score.npy')
OE_LRR_LC_val_loss = np.load('OE_LRR_LC_val_loss.npy')
OE_LRR_LC_val_score = np.load('OE_LRR_LC_val_score.npy')

OE_SVR_LC_train_loss = np.load('OE_SVR_LC_train_loss.npy')
OE_SVR_LC_train_score = np.load('OE_SVR_LC_train_score.npy')
OE_SVR_LC_val_loss = np.load('OE_SVR_LC_val_loss.npy')
OE_SVR_LC_val_score = np.load('OE_SVR_LC_val_score.npy')

OHE_GPR_LC_train_loss = np.load('OHE_GPR_LC_train_loss.npy')
OHE_GPR_LC_train_score = np.load('OHE_GPR_LC_train_score.npy')
OHE_GPR_LC_val_loss = np.load('OHE_GPR_LC_val_loss.npy')
OHE_GPR_LC_val_score = np.load('OHE_GPR_LC_val_score.npy')

OHE_KRR_LC_train_loss = np.load('OHE_KRR_LC_train_loss.npy')
OHE_KRR_LC_train_score = np.load('OHE_KRR_LC_train_score.npy')
OHE_KRR_LC_val_loss = np.load('OHE_KRR_LC_val_loss.npy')
OHE_KRR_LC_val_score = np.load('OHE_KRR_LC_val_score.npy')

OHE_LC_train_loss = np.load('OHE_LC_train_loss.npy')
OHE_LC_train_score = np.load('OHE_LC_train_score.npy')
OHE_LC_val_loss = np.load('OHE_LC_val_loss.npy')
OHE_LC_val_score = np.load('OHE_LC_val_score.npy')

OHE_SVR_LC_train_loss = np.load('OHE_SVR_LC_train_loss.npy')
OHE_SVR_LC_train_score = np.load('OHE_SVR_LC_train_score.npy')
OHE_SVR_LC_val_loss = np.load('OHE_SVR_LC_val_loss.npy')
OHE_SVR_LC_val_score = np.load('OHE_SVR_LC_val_score.npy')

train_size = np.load('CE_GPR_LC_train_size.npy')

# %%
plt.plot(train_size.mean(1), CE_GPR_LC_train_loss.mean(1), "o-", color="#4575b4", label="train_loss")
plt.plot(train_size.mean(1), CE_GPR_LC_val_loss.mean(1), "o-", color="#d73027", label="val_loss")
plt.ylabel('RMSE ('+r'$\AA$)')
plt.xlabel('Train size')
plt.legend()
plt.title('Count Encoding Gaussian Process Regression Learning Curve')
plt.savefig('CE_GPR_LC.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), CE_KRR_LC_train_loss.mean(1), "o-", color="#4575b4", label="train_loss")
plt.plot(train_size.mean(1), CE_KRR_LC_val_loss.mean(1), "o-", color="#d73027", label="val_loss")
plt.ylabel('RMSE ('+r'$\AA$)')
plt.xlabel('Train size')
plt.legend()
plt.title('Count Encoding Kernel Ridge Regression Learning Curve')
plt.savefig('CE_KRR_LC.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), CE_LRR_LC_train_loss.mean(1), "o-", color="#4575b4", label="train_loss")
plt.plot(train_size.mean(1), CE_LRR_LC_val_loss.mean(1), "o-", color="#d73027", label="val_loss")
plt.ylabel('RMSE ('+r'$\AA$)')
plt.xlabel('Train size')
plt.legend()
plt.title('Count Encoding Linear Ridge Regression Learning Curve')
plt.savefig('CE_LRR_LC.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), CE_SVR_LC_train_loss.mean(1), "o-", color="#4575b4", label="train_loss")
plt.plot(train_size.mean(1), CE_SVR_LC_val_loss.mean(1), "o-", color="#d73027", label="val_loss")
plt.ylabel('RMSE ('+r'$\AA$)')
plt.xlabel('Train size')
plt.legend()
plt.title('Count Encoding Support Vector Regression Learning Curve')
plt.savefig('CE_SVR_LC.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), OE_GPR_LC_train_loss.mean(1), "o-", color="#4575b4", label="train_loss")
plt.plot(train_size.mean(1), OE_GPR_LC_val_loss.mean(1), "o-", color="#d73027", label="val_loss")
plt.ylabel('RMSE ('+r'$\AA$)')
plt.xlabel('Train size')
plt.legend()
plt.title('Ordinal Encoding Gaussian Process Regression Learning Curve')
plt.savefig('OE_GPR_LC.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), OE_KRR_LC_train_loss.mean(1), "o-", color="#4575b4", label="train_loss")
plt.plot(train_size.mean(1), OE_KRR_LC_val_loss.mean(1), "o-", color="#d73027", label="val_loss")
plt.ylabel('RMSE ('+r'$\AA$)')
plt.xlabel('Train size')
plt.legend()
plt.title('Ordinal Encoding Kernel Ridge Regression Learning Curve')
plt.savefig('OE_KRR_LC.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), OE_LRR_LC_train_loss.mean(1), "o-", color="#4575b4", label="train_loss")
plt.plot(train_size.mean(1), OE_LRR_LC_val_loss.mean(1), "o-", color="#d73027", label="val_loss")
plt.ylabel('RMSE ('+r'$\AA$)')
plt.xlabel('Train size')
plt.legend()
plt.title('Ordinal Encoding Linear Ridge Regression Learning Curve')
plt.savefig('OE_LRR_LC.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), OE_SVR_LC_train_loss.mean(1), "o-", color="#4575b4", label="train_loss")
plt.plot(train_size.mean(1), OE_SVR_LC_val_loss.mean(1), "o-", color="#d73027", label="val_loss")
plt.ylabel('RMSE ('+r'$\AA$)')
plt.xlabel('Train size')
plt.legend()
plt.title('Ordinal Encoding Support Vector Regression Learning Curve')
plt.savefig('OE_SVR_LC.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), OHE_GPR_LC_train_loss.mean(1), "o-", color="#4575b4", label="train_loss")
plt.plot(train_size.mean(1), OHE_GPR_LC_val_loss.mean(1), "o-", color="#d73027", label="val_loss")
plt.ylabel('RMSE ('+r'$\AA$)')
plt.xlabel('Train size')
plt.legend()
plt.title('One-Hot Encoding Gaussian Process Regression Learning Curve')
plt.savefig('OHE_GPR_LC.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), OHE_LC_train_loss.mean(1), "o-", color="#4575b4", label="train_loss")
plt.plot(train_size.mean(1), OHE_LC_val_loss.mean(1), "o-", color="#d73027", label="val_loss")
plt.ylabel('RMSE ('+r'$\AA$)')
plt.xlabel('Train size')
plt.legend()
plt.title('One-Hot Encoding Linear Ridge Regression Learning Curve')
plt.savefig('OHE_LRR_LC.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), OHE_KRR_LC_train_loss.mean(1), "o-", color="#4575b4", label="train_loss")
plt.plot(train_size.mean(1), OHE_KRR_LC_val_loss.mean(1), "o-", color="#d73027", label="val_loss")
plt.ylabel('RMSE ('+r'$\AA$)')
plt.xlabel('Train size')
plt.legend()
plt.title('One-Hot Encoding Kernel Ridge Regression Learning Curve')
plt.savefig('OHE_KRR_LC.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), OHE_SVR_LC_train_loss.mean(1), "o-", color="#4575b4", label="train_loss")
plt.plot(train_size.mean(1), OHE_SVR_LC_val_loss.mean(1), "o-", color="#d73027", label="val_loss")
plt.ylabel('RMSE ('+r'$\AA$)')
plt.xlabel('Train size')
plt.legend()
plt.title('One-Hot Encoding Support Vector Regression Learning Curve')
plt.savefig('OHE_SVR_LC.png',dpi=400)
plt.show()

# %%
plt.plot(train_size.mean(1), CE_GPR_LC_train_score.mean(1), "o-", color="#4575b4", label="train_score")
plt.plot(train_size.mean(1), CE_GPR_LC_val_score.mean(1), "o-", color="#d73027", label="val_score")
plt.ylabel(r'$R^2$')
plt.xlabel('Train size')
plt.legend()
plt.title('Count Encoding Gaussian Process Regression Learning Curve')
plt.savefig('CE_GPR_LC_score.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), CE_KRR_LC_train_score.mean(1), "o-", color="#4575b4", label="train_score")
plt.plot(train_size.mean(1), CE_KRR_LC_val_score.mean(1), "o-", color="#d73027", label="val_score")
plt.ylabel(r'$R^2$')
plt.xlabel('Train size')
plt.legend()
plt.title('Count Encoding Kernel Ridge Regression Learning Curve')
plt.savefig('CE_KRR_LC_score.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), CE_LRR_LC_train_score.mean(1), "o-", color="#4575b4", label="train_score")
plt.plot(train_size.mean(1), CE_LRR_LC_val_score.mean(1), "o-", color="#d73027", label="val_score")
plt.ylabel(r'$R^2$')
plt.xlabel('Train size')
plt.legend()
plt.title('Count Encoding Linear Ridge Regression Learning Curve')
plt.savefig('CE_LRR_LC_score.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), CE_SVR_LC_train_score.mean(1), "o-", color="#4575b4", label="train_score")
plt.plot(train_size.mean(1), CE_SVR_LC_val_score.mean(1), "o-", color="#d73027", label="val_score")
plt.ylabel(r'$R^2$')
plt.xlabel('Train size')
plt.legend()
plt.title('Count Encoding Support Vector Regression Learning Curve')
plt.savefig('CE_SVR_LC_score.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), OE_GPR_LC_train_score.mean(1), "o-", color="#4575b4", label="train_score")
plt.plot(train_size.mean(1), OE_GPR_LC_val_score.mean(1), "o-", color="#d73027", label="val_score")
plt.ylabel(r'$R^2$')
plt.xlabel('Train size')
plt.legend()
plt.title('Ordinal Encoding Gaussian Process Regression Learning Curve')
plt.savefig('OE_GPR_LC_score.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), OE_KRR_LC_train_score.mean(1), "o-", color="#4575b4", label="train_score")
plt.plot(train_size.mean(1), OE_KRR_LC_val_score.mean(1), "o-", color="#d73027", label="val_score")
plt.ylabel(r'$R^2$')
plt.xlabel('Train size')
plt.legend()
plt.title('Ordinal Encoding Kernel Ridge Regression Learning Curve')
plt.savefig('OE_KRR_LC_score.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), OE_LRR_LC_train_score.mean(1), "o-", color="#4575b4", label="train_score")
plt.plot(train_size.mean(1), OE_LRR_LC_val_score.mean(1), "o-", color="#d73027", label="val_score")
plt.ylabel(r'$R^2$')
plt.xlabel('Train size')
plt.legend()
plt.title('Ordinal Encoding Linear Ridge Regression Learning Curve')
plt.savefig('OE_LRR_LC_score.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), OE_SVR_LC_train_score.mean(1), "o-", color="#4575b4", label="train_score")
plt.plot(train_size.mean(1), OE_SVR_LC_val_score.mean(1), "o-", color="#d73027", label="val_score")
plt.ylabel(r'$R^2$')
plt.xlabel('Train size')
plt.legend()
plt.title('Ordinal Encoding Support Vector Regression Learning Curve')
plt.savefig('OE_SVR_LC_score.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), OHE_GPR_LC_train_score.mean(1), "o-", color="#4575b4", label="train_score")
plt.plot(train_size.mean(1), OHE_GPR_LC_val_score.mean(1), "o-", color="#d73027", label="val_score")
plt.ylabel(r'$R^2$')
plt.xlabel('Train size')
plt.legend()
plt.title('One-Hot Encoding Gaussian Process Regression Learning Curve')
plt.savefig('OHE_GPR_LC_score.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), OHE_LC_train_score.mean(1), "o-", color="#4575b4", label="train_score")
plt.plot(train_size.mean(1), OHE_LC_val_score.mean(1), "o-", color="#d73027", label="val_score")
plt.ylabel(r'$R^2$')
plt.xlabel('Train size')
plt.legend()
plt.title('One-Hot Encoding Linear Ridge Regression Learning Curve')
plt.savefig('OHE_LRR_LC_score.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), OHE_KRR_LC_train_score.mean(1), "o-", color="#4575b4", label="train_score")
plt.plot(train_size.mean(1), OHE_KRR_LC_val_score.mean(1), "o-", color="#d73027", label="val_score")
plt.ylabel(r'$R^2$')
plt.xlabel('Train size')
plt.legend()
plt.title('One-Hot Encoding Kernel Ridge Regression Learning Curve')
plt.savefig('OHE_KRR_LC_score.png',dpi=400)
plt.show()

plt.plot(train_size.mean(1), OHE_SVR_LC_train_score.mean(1), "o-", color="#4575b4", label="train_score")
plt.plot(train_size.mean(1), OHE_SVR_LC_val_score.mean(1), "o-", color="#d73027", label="val_score")
plt.ylabel(r'$R^2$')
plt.xlabel('Train size')
plt.legend()
plt.title('One-Hot Encoding Support Vector Regression Learning Curve')
plt.savefig('OHE_SVR_LC_score.png',dpi=400)
plt.show()
